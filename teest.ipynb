# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from numpy.fft import fft

# %%
t = np.linspace(0,10,1000)
y = np.sin(t)

# %%
plt.plot(t,y,'r')
plt.xlabel('func')
plt.ylabel('time')
plt.show()

# %%
fft = np.fft.fft(y)
for i in range(2):
    print("Value at index {}:\t{}".format(i, fft[i + 1]), "\nValue at index {}:\t{}".format(fft.size -1 - i, fft[-1 - i]))
# Out:
# Value at index 0:	(302.5412075242752+57.15903253445752j)
# Value at index 999:	(302.5412075242752-57.15903253445752j)
# Value at index 1:	(-317.7485822869971-120.27610994690629j)
# Value at index 998:	(-317.7485822869971+120.27610994690629j)

# %%
T = t[1] - t[0]  # sampling interval 
N = y.size

# 1/T = frequency
f = np.linspace(0, 10 / T, N)

plt.ylabel("Amplitude")
plt.xlabel("Frequency [Hz]")
plt.bar(f[:N // 2], np.abs(fft)[:N // 2] * 1 / N, width=1.5)  # 1 / N is a normalization factor
plt.show()
